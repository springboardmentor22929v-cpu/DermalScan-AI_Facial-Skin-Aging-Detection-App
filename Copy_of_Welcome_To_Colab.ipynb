# %%
import os
import zipfile
import cv2
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator


zip_path = "/content/DATASET.zip"
extract_dir = "./dataset"

if not os.path.exists(extract_dir):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_dir)
    print("✅ Dataset extracted successfully!")
else:
    print("✅ Dataset already extracted.")


for root, dirs, files in os.walk(extract_dir):
    print(root, "->", len(files), "files")


IMG_SIZE = (224, 224)
BATCH_SIZE = 32


datagen = ImageDataGenerator(
    rescale=1.0/255,
    validation_split=0.2,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True
)

train_data = datagen.flow_from_directory(
    extract_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    subset='training',
    class_mode='categorical'
)

val_data = datagen.flow_from_directory(
    extract_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    subset='validation',
    class_mode='categorical'
)


images, labels = next(train_data)
print("🖼️ Sample batch shape:", images.shape)
print("🏷️ Labels shape:", labels.shape)
# Out:
# ✅ Dataset extracted successfully!
# ./dataset -> 0 files
# ./dataset/DATASET -> 0 files
# ./dataset/DATASET/dark spots -> 301 files
# ./dataset/DATASET/wrinkles -> 300 files
# ./dataset/DATASET/puffy eyes -> 300 files
# ./dataset/DATASET/clear skin -> 300 files
# Found 961 images belonging to 1 classes.
# Found 240 images belonging to 1 classes.
# 🖼️ Sample batch shape: (32, 224, 224, 3)
# 🏷️ Labels shape: (32, 1)
